# %%
# !pip install gensim

# @title Exp_2_B (Different Dataset)
from gensim.models import Word2Vec

# 1. Mini-corpus (10–15 sentences) → NEW DATASET
corpus = [
    "artificial intelligence is transforming industries",
    "machine learning models learn from data",
    "deep learning uses neural networks",
    "data science involves statistics and programming",
    "python is popular for machine learning",
    "software engineers develop applications",
    "cloud computing provides scalable resources",
    "big data requires efficient processing",
    "cybersecurity protects systems from attacks",
    "databases store and manage information",
    "internet connects people worldwide",
    "students learn programming languages",
    "developers write clean code",
    "technology drives innovation",
    "automation improves efficiency"
]

# 2. Tokenization
sentences = [sentence.split() for sentence in corpus]

# 3. Train Skip-gram model
model = Word2Vec(
    sentences=sentences,
    vector_size=100,
    window=3,
    sg=1,
    min_count=1
)

# 4. Vocabulary
print("Vocabulary:", list(model.wv.index_to_key))

# 5. Query words
query_words = ["data", "learning", "technology"]

# 6. Find similar words
for word in query_words:
    print(f"\nTop 5 similar words to '{word}':")
    for w, score in model.wv.most_similar(word, topn=5):
        print(f"{w} ({score:.4f})")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 33.5 MB/s eta 0:00:00
# ...
# Vocabulary: ['data', 'learning', 'programming', 'and', 'from', 'learn', 'machine', 'is', 'efficiency', 'improves', 'automation', 'innovation', 'drives', 'technology', 'code', 'clean', 'write', 'developers', 'languages', 'students', 'worldwide', 'people', 'connects', 'internet', 'information', 'manage', 'store', 'databases', 'attacks', 'systems', 'protects', 'cybersecurity', 'processing', 'efficient', 'requires', 'big', 'resources', 'scalable', 'provides', 'computing', 'cloud', 'applications', 'develop', 'engineers', 'software', 'for', 'popular', 'python', 'statistics', 'involves', 'science', 'networks', 'neural', 'uses', 'deep', 'models', 'industries', 'transforming', 'intelligence', 'artificial']
#
# Top 5 similar words to 'data':
# write (0.2198)
# improves (0.2161)
# attacks (0.1955)
# uses (0.1723)
# engineers (0.1693)
#
# Top 5 similar words to 'learning':
# databases (0.1889)
# connects (0.1886)
# ...
